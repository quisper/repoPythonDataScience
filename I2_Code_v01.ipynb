# %% [markdown]
# # Exercise 1

# %%
animals = ["Bear","Cat","Ape","Bear","Cat","Bear","Ape","Cat","Bear","Bear","Tiger","Tiger","Ant","Bird","Bird","Tiger","Bear","Ape","Dog","Ant","Ape","Bear","Tiger","Dog","Ant","Tiger","Cat","Ant","Bird","Bear","Dog","Bird","Cat","Tiger","Bear","Bear","Cat","Tiger","Cat","Dog","Ant","Bear","Cat","Ant","Bird","Dog"]
# Which animal is at the 23rd position of the animal list? Store it as r1
r1 = animals[22]
r1
# Out:
# 'Tiger'

# %%
# How often does "Cat" appear in animals? Store this as r2
r2 = animals.count("Cat")
r2
# Out:
# 8

# %%
# Create a list of the unique animal names that appear in animals. Sort this list alphabetically. Store it as r3
r3 = list(set(animals))
r3.sort()
r3
# Out:
# ['Ant', 'Ape', 'Bear', 'Bird', 'Cat', 'Dog', 'Tiger']

# %%
# Remove all animals that start with "B" from the animals list. Store this new list as r4.
# The animals list should stay as it was!
r4 = [animal for animal in animals if "B" not in animal[0]]
r4
# Out:
# ['Cat',
#  'Ape',
#  'Cat',
#  'Ape',
#  'Cat',
#  'Tiger',
#  'Tiger',
#  'Ant',
#  'Tiger',
#  'Ape',
#  'Dog',
#  'Ant',
#  'Ape',
#  'Tiger',
#  'Dog',
#  'Ant',
#  'Tiger',
#  'Cat',
#  'Ant',
#  'Dog',
#  'Cat',
#  'Tiger',
#  'Cat',
#  'Tiger',
#  'Cat',
#  'Dog',
#  'Ant',
#  'Cat',
#  'Ant',
#  'Dog']

# %% [markdown]
# # Exercise 2

# %%
# For some shipments in a supply chain the item, the item category, 
# the shipped amount and the returned amount (in cases) is given
item = ["sparkling water","blueberry muffin","lids","blueberry muffin","decaffeinated coffee","milk chocolate","milk chocolate","lemonade","chicken sandwich","plain bagel","milk","strawberry yogurt","nuts and raisins","nuts and raisins","cups","almond croissant","iced tea","cups","milk chocolate","spring salad","grilled cheese sandwich","decaffeinated coffee","cups","sparkling water","granola bar","egg salad sandwich","orange juice","milk","milk chocolate","blueberry muffin","cranberry and almond bar","lids","lemonade","marble pound cake","milk","iced tea","salmon bistro box","marble pound cake","milk chocolate","strawberry yogurt","whipped cream","almond croissant","sparkling water","oatmeal","scone","cranberry and almond bar","chicken sandwich","lemonade","scone","cranberry and almond bar","spring salad","lemonade","cinnamon bagel","apple juice","cups","oatmeal","nuts and raisins","lids","sparkling water","milk","egg salad sandwich","iced tea","salmon bistro box","sparkling water","marble pound cake","plain bagel","milk","cups","grilled cheese sandwich","nuts and raisins","nuts and raisins","chocolate croissant","spring salad","granola bar","lids","cranberry and almond bar","egg salad sandwich","egg salad sandwich","cranberry and almond bar","decaffeinated coffee","almond croissant","lemonade","lids","sparkling water","apple juice","salmon bistro box","whipped cream","lemonade","strawberry yogurt","orange juice","almond croissant","cinnamon bagel","marble pound cake","orange juice","chocolate croissant","cups","oatmeal","sparkling water","normal coffee","blueberry muffin","blueberry muffin","nuts and raisins","nuts and raisins","scone","milk","decaffeinated coffee","iced tea","granola bar","lids","milk","oatmeal","normal coffee","salmon bistro box","lemonade","cinnamon bagel","normal coffee","almond croissant"]
category = ["beverage","bakery","container","bakery","coffee","packaged food","packaged food","beverage","prepared food","bakery","dairy","prepared food","packaged food","packaged food","container","bakery","beverage","container","packaged food","prepared food","prepared food","coffee","container","beverage","packaged food","prepared food","beverage","dairy","packaged food","bakery","packaged food","container","beverage","bakery","dairy","beverage","prepared food","bakery","packaged food","prepared food","dairy","bakery","beverage","packaged food","bakery","packaged food","prepared food","beverage","bakery","packaged food","prepared food","beverage","bakery","beverage","container","packaged food","packaged food","container","beverage","dairy","prepared food","beverage","prepared food","beverage","bakery","bakery","dairy","container","prepared food","packaged food","packaged food","bakery","prepared food","packaged food","container","packaged food","prepared food","prepared food","packaged food","coffee","bakery","beverage","container","beverage","beverage","prepared food","dairy","beverage","prepared food","beverage","bakery","bakery","bakery","beverage","bakery","container","packaged food","beverage","coffee","bakery","bakery","packaged food","packaged food","bakery","dairy","coffee","beverage","packaged food","container","dairy","packaged food","coffee","prepared food","beverage","bakery","coffee","bakery"]
shipped = [49,25,41,28,49,28,25,37,49,41,23,21,37,44,38,48,21,50,26,26,33,39,25,42,37,43,35,38,43,24,47,22,27,44,21,43,34,42,39,29,25,20,36,39,45,50,34,25,43,35,28,21,34,21,35,25,31,23,45,39,31,40,46,28,35,46,36,46,43,21,47,30,40,36,24,28,32,30,27,36,41,43,42,32,40,26,41,40,33,40,41,45,43,36,46,30,40,42,39,40,48,44,36,49,27,31,26,23,22,44,50,38,35,36,20,36,31]
returned = [1,0,7,7,0,1,9,1,4,8,10,9,0,9,2,7,3,6,7,1,6,4,1,0,1,6,2,7,5,1,2,4,4,5,7,4,7,4,1,5,2,6,0,7,8,4,1,7,5,0,9,1,0,6,8,6,7,10,9,5,9,0,1,0,10,7,4,2,8,8,9,4,7,7,5,5,1,6,1,6,3,2,8,9,0,9,3,10,9,1,4,8,2,2,10,1,0,3,1,10,8,8,4,8,6,8,2,2,7,7,4,4,9,7,4,6,9]
# How many cases were shipped in total? Store this number as r5
r5 = sum(shipped)
r5
# Out:
# 4145

# %%
# What is the total return ratio, i.e. the total number of returns divided by the total number of shipments?
# Store this ratio (number between 0-1) as r6
r6 = sum(returned)/sum(shipped)
r6
# Out:
# 0.1367913148371532

# %%
# What is the return ratio for the category "bakery"? Store this number as r7
sum_Returned = 0
sum_Shipped = 0
for i in range(len(returned)):
  if category[i] == "bakery":
    sum_Returned = sum_Returned + returned[i] 
    sum_Shipped = sum_Shipped + shipped[i]

r7 = sum_Returned/sum_Shipped
r7
# Out:
# 0.15181518151815182

# %%
# Which item has the lowest return ratio? Store this item name as r8
lowest_ratio = 20
r8 = ""
for i in range(len(item)):
  sum_Returned = 0
  sum_Shipped = 0
  for j in range(len(returned)):
    if item[i] == item[j]:
      sum_Returned = sum_Returned + returned[j] 
      sum_Shipped = sum_Shipped + shipped[j]
  if sum_Returned/sum_Shipped < lowest_ratio:
    lowest_ratio = sum_Returned/sum_Shipped
    r8 = item[i]

print("item: ",r8)
print("lowest ratio:",lowest_ratio)
# Out:
# item:  orange juice
# lowest ratio: 0.04504504504504504

# %% [markdown]
# # Exercise 3

# %%
# Given are the following customer data
customers = {7078:{'Name':'Lily Carter','City':'London','Sales':10,'Visits':31},8652:{'Name':'Scarlett Thomas','City':'Manchester','Sales':38,'Visits':53},5120:{'Name':'Sophie Martin','City':'London','Sales':18,'Visits':53},5179:{'Name':'Lily Evans','City':'London','Sales':3,'Visits':59},1133:{'Name':'Ava Adams','City':'Birmingham','Sales':29,'Visits':29},1154:{'Name':'Alfie Thompson','City':'London','Sales':28,'Visits':31},9196:{'Name':'Freddie Wright','City':'London','Sales':39,'Visits':100},7353:{'Name':'Charlie Watson','City':'London','Sales':35,'Visits':39},7551:{'Name':'Archie Thomas','City':'Sheffield','Sales':27,'Visits':86},7937:{'Name':'Freya Moore','City':'London','Sales':34,'Visits':56},4804:{'Name':'Charlie Hill','City':'London','Sales':14,'Visits':24},1436:{'Name':'Freya Wright','City':'London','Sales':20,'Visits':21},9847:{'Name':'Jessica Hall','City':'Manchester','Sales':15,'Visits':22},7577:{'Name':'Scarlett Wood','City':'London','Sales':4,'Visits':94},9195:{'Name':'Freya Wood','City':'Birmingham','Sales':33,'Visits':86},6377:{'Name':'George Carter','City':'Birmingham','Sales':5,'Visits':87},4143:{'Name':'Oliver Clarke','City':'Birmingham','Sales':21,'Visits':54},8495:{'Name':'Jessica Robinson','City':'Birmingham','Sales':29,'Visits':76},7789:{'Name':'Charlie Turner','City':'Birmingham','Sales':32,'Visits':70},8186:{'Name':'Jack Roberts','City':'Birmingham','Sales':16,'Visits':65},5519:{'Name':'Leo Ward','City':'Birmingham','Sales':8,'Visits':23},9989:{'Name':'Jack Anderson','City':'Birmingham','Sales':38,'Visits':97},7620:{'Name':'Isabella James','City':'Birmingham','Sales':28,'Visits':54},4247:{'Name':'Alice Patel','City':'Birmingham','Sales':28,'Visits':92},4332:{'Name':'Ethan Hall','City':'Birmingham','Sales':9,'Visits':25},3553:{'Name':'William Patel','City':'Birmingham','Sales':22,'Visits':76},2417:{'Name':'Mia Evans','City':'Sheffield','Sales':22,'Visits':45},3882:{'Name':'Isabella Hill','City':'Sheffield','Sales':20,'Visits':28},1850:{'Name':'William James','City':'Sheffield','Sales':20,'Visits':29},1386:{'Name':'William Cooper','City':'Sheffield','Sales':6,'Visits':35},3137:{'Name':'Leo Williams','City':'Cambridge','Sales':37,'Visits':67},5847:{'Name':'Ethan Cooper','City':'Cambridge','Sales':35,'Visits':36},1644:{'Name':'Jessica King','City':'Cambridge','Sales':22,'Visits':50},3197:{'Name':'Jack White','City':'Sheffield','Sales':3,'Visits':59},2148:{'Name':'Ella Robinson','City':'Sheffield','Sales':32,'Visits':79},9929:{'Name':'Muhammad Walker','City':'London','Sales':14,'Visits':37},2474:{'Name':'Freddie King','City':'Sheffield','Sales':14,'Visits':49},9071:{'Name':'Lily Lee','City':'Sheffield','Sales':23,'Visits':53},6058:{'Name':'Olivia Anderson','City':'Leeds','Sales':39,'Visits':52},8421:{'Name':'Ethan Thompson','City':'Leeds','Sales':40,'Visits':44},9938:{'Name':'Joshua Ward','City':'Leeds','Sales':18,'Visits':58},3805:{'Name':'Isabella Walker','City':'Sheffield','Sales':19,'Visits':101},5977:{'Name':'Henry Green','City':'Sheffield','Sales':27,'Visits':85},4787:{'Name':'Jessica Lewis','City':'Sheffield','Sales':13,'Visits':72},3468:{'Name':'Sophie White','City':'Leeds','Sales':3,'Visits':24},5100:{'Name':'Freddie Martin','City':'Leeds','Sales':10,'Visits':100},6277:{'Name':'Harry Wood','City':'Leeds','Sales':29,'Visits':102},6034:{'Name':'Leo James','City':'Leeds','Sales':36,'Visits':63},7589:{'Name':'Grace Clarke','City':'Leeds','Sales':5,'Visits':42},9376:{'Name':'Isla Brown','City':'Leeds','Sales':23,'Visits':50},1622:{'Name':'Jacob Jackson','City':'Leeds','Sales':14,'Visits':50},6961:{'Name':'Leo Evans','City':'Leeds','Sales':9,'Visits':93},2503:{'Name':'Scarlett Campbell','City':'Leeds','Sales':36,'Visits':71},7211:{'Name':'Muhammad Harris','City':'Manchester','Sales':40,'Visits':71},3682:{'Name':'Emily Roberts','City':'Manchester','Sales':5,'Visits':57},9381:{'Name':'Ella Jones','City':'Manchester','Sales':40,'Visits':75},9506:{'Name':'Muhammad Harrison','City':'Manchester','Sales':3,'Visits':94},8935:{'Name':'Ava Campbell','City':'Manchester','Sales':3,'Visits':27},2025:{'Name':'Alice Anderson','City':'Manchester','Sales':20,'Visits':81},3230:{'Name':'Ethan Thomas','City':'London','Sales':12,'Visits':29},7779:{'Name':'Joshua Morgan','City':'Cambridge','Sales':20,'Visits':22},9806:{'Name':'Jessica Lewis','City':'Cambridge','Sales':32,'Visits':69},6706:{'Name':'Muhammad Thompson','City':'Manchester','Sales':24,'Visits':27},2462:{'Name':'Alice Adams','City':'Manchester','Sales':33,'Visits':67},8032:{'Name':'Olivia Wright','City':'Manchester','Sales':34,'Visits':92},8337:{'Name':'Scarlett Walker','City':'Manchester','Sales':5,'Visits':67},5749:{'Name':'Ella Adams','City':'Manchester','Sales':8,'Visits':80},3151:{'Name':'Alfie Scott','City':'Manchester','Sales':13,'Visits':37},1925:{'Name':'George Wood','City':'Manchester','Sales':19,'Visits':60},5118:{'Name':'Sophie Smith','City':'Birmingham','Sales':21,'Visits':77},9110:{'Name':'Mia Thomas','City':'Liverpool','Sales':38,'Visits':78},1479:{'Name':'Mia Harrison','City':'Liverpool','Sales':8,'Visits':99},1209:{'Name':'George Clarke','City':'Liverpool','Sales':26,'Visits':49},5557:{'Name':'Alice Allen','City':'Liverpool','Sales':1,'Visits':50},4059:{'Name':'Jessica King','City':'Liverpool','Sales':10,'Visits':93},7158:{'Name':'Isabella Robinson','City':'London','Sales':26,'Visits':36},6739:{'Name':'Olivia Phillips','City':'Liverpool','Sales':40,'Visits':48},2672:{'Name':'Leo Clarke','City':'Liverpool','Sales':7,'Visits':73},8616:{'Name':'Freya Thompson','City':'Liverpool','Sales':3,'Visits':24},6203:{'Name':'Ava Jackson','City':'Liverpool','Sales':6,'Visits':45},4032:{'Name':'George Taylor','City':'Liverpool','Sales':18,'Visits':80},4184:{'Name':'George Lee','City':'Cambridge','Sales':27,'Visits':40},8828:{'Name':'Muhammad King','City':'Cambridge','Sales':20,'Visits':51},2693:{'Name':'Jack Robinson','City':'Cambridge','Sales':15,'Visits':86},4850:{'Name':'Noah Clarke','City':'Cambridge','Sales':10,'Visits':86},2588:{'Name':'Ella Adams','City':'Liverpool','Sales':18,'Visits':99},1645:{'Name':'Florence Morris','City':'Liverpool','Sales':10,'Visits':76},8223:{'Name':'Muhammad Scott','City':'Liverpool','Sales':8,'Visits':51},5390:{'Name':'Freddie Brown','City':'Sheffield','Sales':24,'Visits':90},9693:{'Name':'Mia Taylor','City':'Sheffield','Sales':6,'Visits':66},2829:{'Name':'Ella Taylor','City':'Sheffield','Sales':22,'Visits':60},2690:{'Name':'Mia Scott','City':'London','Sales':39,'Visits':95},6996:{'Name':'Ava Edwards','City':'Norwich','Sales':3,'Visits':49},8797:{'Name':'Joshua White','City':'Norwich','Sales':17,'Visits':75},2234:{'Name':'Isaac Lewis','City':'Norwich','Sales':10,'Visits':14},2128:{'Name':'Freya Patel','City':'London','Sales':12,'Visits':30},8036:{'Name':'Freya Thomas','City':'London','Sales':40,'Visits':61},9009:{'Name':'Charlie Harrison','City':'London','Sales':22,'Visits':23},3049:{'Name':'Freya Clarke','City':'London','Sales':1,'Visits':63},1721:{'Name':'Jessica Allen','City':'Norwich','Sales':12,'Visits':99},7855:{'Name':'Scarlett King','City':'Norwich','Sales':29,'Visits':88},8547:{'Name':'Freya Robinson','City':'Norwich','Sales':29,'Visits':55},5941:{'Name':'George Phillips','City':'Norwich','Sales':34,'Visits':51},5765:{'Name':'Oliver Clarke','City':'London','Sales':38,'Visits':93},2180:{'Name':'Jessica Thompson','City':'Norwich','Sales':17,'Visits':70},3672:{'Name':'Charlie Jackson','City':'Cambridge','Sales':10,'Visits':16},8499:{'Name':'Jack Taylor','City':'Cambridge','Sales':19,'Visits':78},3009:{'Name':'Leo Lee','City':'Cambridge','Sales':2,'Visits':5},6457:{'Name':'Jack King','City':'Cambridge','Sales':32,'Visits':34},8393:{'Name':'Isabella Robinson','City':'Cambridge','Sales':35,'Visits':85},8514:{'Name':'Alice Clarke','City':'Cambridge','Sales':21,'Visits':99},6120:{'Name':'Ethan Adams','City':'Cambridge','Sales':6,'Visits':14},3499:{'Name':'William Morris','City':'Cambridge','Sales':3,'Visits':80},5550:{'Name':'Mia Scott','City':'London','Sales':11,'Visits':94},3800:{'Name':'Isabella Brown','City':'Cambridge','Sales':21,'Visits':45},8112:{'Name':'William Taylor','City':'Cambridge','Sales':24,'Visits':56}}

# %%
# What is the name of customer 3682? Store this as r9
r9 = customers[3682]['Name']
r9
# Out:
# 'Emily Roberts'

# %%
# Which customer has the most visits? Store his or her ID as r10
r10 = 0
most_visits = 0
for i in customers:
  if customers[i]['Visits'] > most_visits:
    r10 = i
    most_visits = customers[i]['Visits']

print("most visits ID: ",r10)
print(customers[r10])
# Out:
# most visits ID:  6277
# {'Name': 'Harry Wood', 'City': 'Leeds', 'Sales': 29, 'Visits': 102}
